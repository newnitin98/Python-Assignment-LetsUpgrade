# %%
print ("hi")
# Out:
# hi

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print ("run this code")
# Out:
# run this code

# %%
print ("How to run this code; see below comment")

#shift + Enter Key
# Out:
# How to run this code; see below comment

# %% [markdown]
# # Python Tutorial Class Day 1

# %%
while True:
    print ("hi")
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...

# %%
print ("Hello \
       Python")
# Out:
# Hello        Python

# %% [markdown]
# # Day 2 Python Ess

# %%
print ("Python's World")
# Out:
# Python's World

# %%
print ("Python \n world")
# Out:
# Python
#  world

# %%
print ('Python\'s world')
# Out:
# Python's world

# %%
Name = "Nitin Sharma"
Marks = 90.879
Age = 30
print ("Name of the Person",Name,"Marks Obtained",Marks,"Age of the Person",Age,)
# Out:
# Name of the Person Nitin Sharma Marks Obtained 90.87 Age of the Person 30

# %%
print ("Name of the Person %10s Marks Obtained %10f Age of the person %10d"%(Name,Marks,Age))
# Out:
# Name of the Person Nitin Sharma Marks Obtained  90.870000 Age of the person         30

# %%
print ("Name of the Person %10s Marks Obtained %10.2f Age of the person %10d"%(Name,Marks,Age))
# Out:
# Name of the Person Nitin Sharma Marks Obtained      90.87 Age of the person         30

# %%
print("Hello\aWorld")
# Out:
# HelloWorld

# %%
Using f string

# %%
print (f"Name of the Person {Name} Marks obtained {Marks} age of the person {Age}")
# Out:
# Name of the Person Nitin Sharma Marks obtained 90.87 age of the person 30

# %%
x=10

# %%
y=10

# %%
z=x+y

# %%
z
# Out:
# 20

# %%
id(x)
# Out:
# 140715339588272

# %%
id(y)
# Out:
# 140715339588272

# %%
x**2
# Out:
# 100

# %%
x/y
# Out:
# 1.0

# %%
x%y
# Out:
# 0

# %%
x*y
# Out:
# 100

# %%
x-y
# Out:
# 0

# %%
x//y
# Out:
# 1

# %%
z//x
# Out:
# 2

# %%
a=10
b=20

# %%
c=30

# %%
a==b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a==c
# Out:
# False

# %%
d=10

# %%
a==d
# Out:
# True

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=240
b=1

# %%
a|b
# Out:
# 241

# %%
a&b
# Out:
# 0

# %%
bin(a)
# Out:
# '0b11110000'

# %%
bin(b)
# Out:
# '0b1'

# %%
a=1
b=20

# %%
a>b
# Out:
# False

# %%
a>10 or b <15
# Out:
# False

# %%
a<1 or b >15
# Out:
# True

# %%
a==1 and b >10
# Out:
# True

# %%
str1 = "PythonProgramming"
"a" in str1
# Out:
# True

# %%
"z" in str1
# Out:
# False

# %%
x=10
y=10

# %%
x is y
# Out:
# True

# %%
x is not y
# Out:
# False

# %%
id(x)
# Out:
# 140715339588272

# %%
id(y)
# Out:
# 140715339588272

# %%
a=257
b=257

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True
